# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the Pareto distribution
alpha = 1.5   # shape parameter (tail exponent)
x_m = 25     # scale parameter (minimum value)
size = 100000  # number of samples

# Generate Pareto-distributed samples
samples = (np.random.pareto(alpha, size) + 1) * x_m

# Plot the distribution
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=500, density=True)
plt.title(f"Pareto Distribution (α={alpha}, xₘ={x_m})")
plt.xlabel("Value")
plt.ylabel("Density")
plt.xlim(x_m, np.percentile(samples, 99.9))  # focus on the bulk by clipping the extreme tail
plt.show()
